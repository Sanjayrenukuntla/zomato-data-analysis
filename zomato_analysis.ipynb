# %% [markdown]
# # **Zomato Data Analysis Using Python**

# %% [markdown]
# 1 :Upload Dataset in colob (or) directly copy drive file path

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6eaade50-f640-42e8-b158-914dc72f0694" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6eaade50-f640-42e8-b158-914dc72f0694">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# 2 .Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#for better visuals
sns.set(style='whitegrid')

# %% [markdown]
# 3 .load Dataset

# %%
df = pd.read_csv("Zomato.csv")

#Clean Column Names
df.columns = df.columns.str.replace(" ", "_")
df.columns = df.columns.str.replace("(", "")
df.columns = df.columns.str.replace(")", "")
df['rate'] = df['rate'].str.split('/').str[0] # To Clean the column
df['rate'] = pd.to_numeric(df['rate'], errors='coerce') #To Convert to float
df = df.dropna(subset=['rate'])

df.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_costfor_two_people listed_intype
# 0                        800        Buffet
# 1                        800        Buffet
# 2                        800        Buffet
# 3                        300        Buffet
# 4                        600        Buffet

# %% [markdown]
# 4 .Basic Exploration

# %%
# print('shape:',df.shape)
# df.info()
# df.describe()
# df.isnull().sum()

# %% [markdown]
# 5 .Data cleaning

# %%
#remove missing values
df.dropna(inplace = True)
#Remove Duplicates
df.drop_duplicates(inplace = True)

# %% [markdown]
# 6 .Ratings Distribution

# %%
# Analyze rating distribution to understand customer satisfaction
plt.figure(figsize=(8,5))

sns.histplot(df['rate'], bins=10)

plt.title("Ratings Distribution")
plt.xlabel("Rating")
plt.ylabel("Count")

plt.show()

# Insight:
# Most restaurants have ratings between 3.5 and 4.0.

# %% [markdown]
# 7 .Cost Distribution

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['approx_costfor_two_people'], bins=10)

plt.title('Cost Distribution')
plt.xlabel('Cost')
plt.ylabel('Count')

plt.show()

# Insight:
# Most restaurants fall in the mid-cost range.

# %% [markdown]
# 8 .Online Order vs Ratings

# %%
plt.figure(figsize=(6,4))

sns.boxplot(x='online_order', y='rate', data=df)

plt.title('Online Order vs Rating')

plt.show()

# Insight:
# Restaurants offering online orders have slightly higher ratings.

# %% [markdown]
# 9.Table Booking vs Ratings

# %%
plt.figure(figsize=(6,4))

sns.boxplot(x='book_table', y='rate', data=df)

plt.title('Table Booking vs Rating')

plt.show()

# Insight:
# Restaurants with table booking tend to have higher ratings.

# %% [markdown]
# 10.Correlation Heatmap

# %%
plt.figure(figsize=(6,4))

corr = df.corr(numeric_only=True)

sns.heatmap(corr, annot=True, cmap="coolwarm")

plt.title("Correlation Matrix")

plt.show()

# Insight:
# There is a positive relationship between cost and votes.

# %% [markdown]
# 11.Top Restaurant Types

# %%
df['listed_intype'].value_counts().head(10)
